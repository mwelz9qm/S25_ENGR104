# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('sensor_data.csv')
df
# Out:
#           Date    Location Sensor_ID  Temperature_C  Humidity  PM2.5
# 0   2024-01-01  Location_A  Sensor_1           22.5        45   12.4
# 1   2024-01-01  Location_A  Sensor_2           21.8        47   10.2
# 2   2024-01-01  Location_B  Sensor_3           19.2        50    9.5
# 3   2024-01-02  Location_A  Sensor_1           23.1        43   11.7
# 4   2024-01-02  Location_A  Sensor_2           22.4        46   10.9
# 5   2024-01-02  Location_B  Sensor_3           20.5        48    8.6
# 6   2024-01-03  Location_A  Sensor_1           24.0        42   12.0
# 7   2024-01-03  Location_A  Sensor_2           23.2        44   11.1
# 8   2024-01-03  Location_B  Sensor_3           21.0        49    9.0
# 9   2024-01-04  Location_A  Sensor_1           24.5        40   13.0
# 10  2024-01-04  Location_A  Sensor_2           23.8        42   12.3
# 11  2024-01-04  Location_B  Sensor_3           22.1        47   10.0
# 12  2024-01-05  Location_A  Sensor_1           25.0        39   13.5
# ...

# %%
df = df.set_index('Date')  #resets the index of the dataframe to be the data column
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20412\340103043.py in ?()
# ----> 1 df = df.set_index('Date')  #resets the index of the dataframe to be the data column
#       2 df
#
# C:\ProgramData\Anaconda\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5866                     if not found:
#    5867                         missing.append(col)
#    5868
#    5869         if missing:
# -> 5870             raise KeyError(f"None of {missing} are in the columns")
#    5871
#    5872         if inplace:
#    5873             frame = self
#
# KeyError: "None of ['Date'] are in the columns"

# %%
df
# Out:
#               Location Sensor_ID  Temperature_C  Humidity  PM2.5
# Date
# 2024-01-01  Location_A  Sensor_1           22.5        45   12.4
# 2024-01-01  Location_A  Sensor_2           21.8        47   10.2
# 2024-01-01  Location_B  Sensor_3           19.2        50    9.5
# 2024-01-02  Location_A  Sensor_1           23.1        43   11.7
# 2024-01-02  Location_A  Sensor_2           22.4        46   10.9
# 2024-01-02  Location_B  Sensor_3           20.5        48    8.6
# 2024-01-03  Location_A  Sensor_1           24.0        42   12.0
# 2024-01-03  Location_A  Sensor_2           23.2        44   11.1
# 2024-01-03  Location_B  Sensor_3           21.0        49    9.0
# 2024-01-04  Location_A  Sensor_1           24.5        40   13.0
# 2024-01-04  Location_A  Sensor_2           23.8        42   12.3
# 2024-01-04  Location_B  Sensor_3           22.1        47   10.0
# 2024-01-05  Location_A  Sensor_1           25.0        39   13.5
# ...

# %%
fig, ax = plt.subplots()
df['Humidity'].plot.bar(color = 'purple', edgecolor = 'black') #prints a bar plot of the humidity column
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Next we'll learn how to add a column to a data frame and after that, we'll make a data frame from scratch. We'll make a column for the fahreneit temp which uses the formula $F = 1.8C + 32$.

# %%
df['Temperature_F'] = 1.8 * df['Temperature_C'] + 32
df
# Out:
#               Location Sensor_ID  Temperature_C  Humidity  PM2.5  \
# Date
# 2024-01-01  Location_A  Sensor_1           22.5        45   12.4
# 2024-01-01  Location_A  Sensor_2           21.8        47   10.2
# 2024-01-01  Location_B  Sensor_3           19.2        50    9.5
# 2024-01-02  Location_A  Sensor_1           23.1        43   11.7
# 2024-01-02  Location_A  Sensor_2           22.4        46   10.9
# 2024-01-02  Location_B  Sensor_3           20.5        48    8.6
# 2024-01-03  Location_A  Sensor_1           24.0        42   12.0
# 2024-01-03  Location_A  Sensor_2           23.2        44   11.1
# 2024-01-03  Location_B  Sensor_3           21.0        49    9.0
# 2024-01-04  Location_A  Sensor_1           24.5        40   13.0
# 2024-01-04  Location_A  Sensor_2           23.8        42   12.3
# 2024-01-04  Location_B  Sensor_3           22.1        47   10.0
# 2024-01-05  Location_A  Sensor_1           25.0        39   13.5
# ...

# %% [markdown]
# We're going to create a dataframe from scratch.

# %%
myDf = pd.DataFrame()
# Adding a column of names
myDf['Name'] = ['Alice', 'Bob', 'Charlie', 'David', 'Eva']

# Adding a column of ages
myDf['Age'] = [25, 30, 35, 40, 45]

# Adding a column of city
myDf['City'] = ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix']

myDf
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston
# 4      Eva   45      Phoenix

# %%
#alternate approach to creating a new dataframe

friends = {'Names':['Alice', 'Bob', 'Charlie'], 'Ages': [25,30,35]}
newDf = pd.DataFrame(friends)
newDf
# Out:
#      Names  Ages
# 0    Alice    25
# 1      Bob    30
# 2  Charlie    35
